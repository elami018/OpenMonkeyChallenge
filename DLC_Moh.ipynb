# %% [markdown]
# Author: @Mouhamad Ali Elamine *elami018@umn.edu 2022*

# %%
pip install deeplabcut

# %%
import deeplabcut
# Out:
# Loading DLC 2.2.3...
# DLC loaded in light mode; you cannot use any GUI (labeling, relabeling and standalone GUI)

# %%
# %cd /content/drive/Shareddrives/computervision/Benchmark-Rishi-2022-12-09
# Out:
# /content/drive/Shareddrives/computervision/Benchmark-Rishi-2022-12-09

# %% [markdown]
# Begin Training with the following Parameters.
# ```python
# (
#   max_snapshots_to_keep=5
#   shuffle=1
#   saveiters=20,000 #(saves at every 10%)
#   maxiters=200,000 #(Based on reccomendation by @Matthis)
#   displayiters=100
#   autotune=False #(Works faster in TensorFlow)
#   allow_growth=True
# )
# ```
# For more information refer to  the [training-section](https://deeplabcut.github.io/DeepLabCut/docs/standardDeepLabCut_UserGuide.html#g-train-the-network).

# %%
deeplabcut.train_network('/content/drive/Shareddrives/computervision/Benchmark-Rishi-2022-12-09/config.yaml', shuffle=1, trainingsetindex=0, max_snapshots_to_keep=5, displayiters=50, saveiters=5000, maxiters=200000, allow_growth=True, autotune=False, modelprefix='')

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('/content/drive/Shareddrives/computervision/Benchmark-Rishi-2022-12-09/dlc-models/iteration-0/BenchmarkDec9-trainset95shuffle1/train/learning_stats.csv')
plt.plot(df.iloc[:,0],df.iloc[:,1], color='green')
plt.xlabel('Iteration Number')
plt.ylabel('Loss')
plt.title('Error of training model on training data with weights of pre-trained model on validation')
# Out:
# Text(0.5, 1.0, 'Error of training model on training data with weights of pre-trained model on validation')

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('/content/drive/Shareddrives/computervision/Benchmark-Rishi-2022-12-09/dlc-models/iteration-0/BenchmarkDec9-trainset95shuffle1/train/learning_stats_2.csv')
plt.plot(df.iloc[:,0],df.iloc[:,1], color='green')
plt.xlabel('Iteration Number')
plt.ylabel('Loss')
plt.title('Error of training model on training data with weights of pre-trained model on validation')
# Out:
# Text(0.5, 1.0, 'Error of training model on training data with weights of pre-trained model on validation')

# %% [markdown]
# Analyze the images with the following Parameters.
# ```python
# (
#   config_path='/content/drive/Shareddrives/computervision/Benchmark-Rishi-2022-12-09/config.yaml'
#   save_as_csv=True #required for manual analysis
#   videotype='.jpg' #using pre-annotated images
#   destfolder='/content/drive/Shareddrives/computervision/Benchmark-Rishi-2022-12-09/dlc-models/iteration-0/BenchmarkDec7-trainset95shuffle1/test'
# )
# ```
# For more information refer to the following [documentation](https://deeplabcut.github.io/DeepLabCut/docs/standardDeepLabCut_UserGuide.html#l-create-labeled-videos)

# %%
deeplabcut.analyze_videos('/content/drive/Shareddrives/computervision/Benchmark-Rishi-2022-12-09/config.yaml',
                          ['/content/drive/Shareddrives/computervision/Benchmark-Rishi-2022-12-09/labeled-data/vid2/train70k'],
                          save_as_csv=True,
                          videotype='.jpg',
                          destfolder='/content/drive/Shareddrives/computervision/Benchmark-Rishi-2022-12-09/dlc-models/iteration-0/BenchmarkDec9-trainset95shuffle1/test')

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('/content/drive/Shareddrives/computervision/Benchmark-Rishi-2022-12-09/dlc-models/iteration-0/BenchmarkDec9-trainset95shuffle1/train/learning_stats.csv')
